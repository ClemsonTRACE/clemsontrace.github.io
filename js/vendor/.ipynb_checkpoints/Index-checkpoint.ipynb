# %%
a
# Out:
# ...
# {'affiliation': 'Assistant Professor of Human-Centered Computing; Director, '
#                 'TRACE Research Group Clemson University',
#  'citedby': 547,
#  'citedby5y': 497,
#  'cites_per_year': {2009: 2,
#                     2010: 1,
#                     2011: 2,
#                     2012: 13,
#                     2013: 11,
#                     2014: 18,
#                     2015: 38,
#                     2016: 42,
#                     2017: 90,
#                     2018: 96,
#                     2019: 133,
#                     2020: 96},
#  'coauthors': [{'affiliation': 'Senior Quantitative Scientist, Arizona State University',
#  'filled': False,
#  'id': 'X41iFxEAAAAJ',
#  'name': 'Mustafa Demir'},
#                {'affiliation': 'Professor of Communication Studies and Associate Dean for '
#                 'Graduate Programs, Northwestern University',
#  'filled': False,
#  'id': 'ZD-2ddIAAAAJ',
#  'name': 'Madhu Reddy'},
# ...
