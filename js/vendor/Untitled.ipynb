# %%
# !sudo apt update -y
# !sudo apt install python3-pip -y

# %%
# !pip3 install scholarly

from scholarly import scholarly

search_query = scholarly.search_author('Nathan J. McNeese')
author = next(search_query)
print(author.fill(sections=['publications']))
# Out:
# ...
# {'affiliation': 'Assistant Professor of Human-Centered Computing; Director, '
#                 'TRACE Research Group …',
#  'citedby': 547,
#  'email': '@clemson.edu',
#  'filled': False,
#  'id': 'G1CnZ38AAAAJ',
#  'interests': ['Human Factors',
#                'HCI',
#                'Team Cognition',
#                'Artificial Intelligence'],
#  'name': 'Nathan J. McNeese',
#  'publications': [{'bib': {'cites': '169',
#          'title': 'Classifying text messages for the haiti earthquake.',
#          'year': '2011'},
#  'filled': False,
#  'id_citations': 'G1CnZ38AAAAJ:5nxA0vEk-isC',
#  'source': 'citations'},
#                   {'bib': {'cites': '45',
#          'title': 'Teaming with a synthetic teammate: Insights into '
#                   'human-autonomy teaming',
#          'year': '2018'},
#  'filled': False,
#  'id_citations': 'G1CnZ38AAAAJ:4JMBOYKVnBMC',
#  'source': 'citations'},
#                   {'bib': {'cites': '39',
# ...
